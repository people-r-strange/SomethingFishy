# %%
import numpy as np
import pandas as pd
from datetime import date, timedelta, datetime
from dateutil.relativedelta import relativedelta
from pandas import Series, DataFrame

# %% [raw]
# READING IN DATA

# %%
df = pd.read_excel("Voter Registry.xls")

# %%
#making sure all string type is same format
df['LAST NAME'] = df['LAST NAME'].str.upper()

df['FIRST NAME'] = df['FIRST NAME'].str.upper()

df['POB'] = df['POB'].str.upper()

df['SEX'] = df['SEX'].str.upper()

df['STREET NAME'] = df['STREET NAME'].str.upper()

df['PARTY '] = df['PARTY '].str.upper()

# %%
df
# Out:
#               Unnamed: 0  LAST NAME FIRST NAME                  DOB  \
# 0      SYNTHETIC DATASET      SMITH       ALEX  1917-01-05 00:00:00
# 1      SYNTHETIC DATASET    JOHNSON     BONNIE  1916-01-07 00:00:00
# 2      SYNTHETIC DATASET   WILLIAMS    CHARLEY  1913-02-07 00:00:00
# 3      SYNTHETIC DATASET      JONES   DANIELLE  1915-11-05 00:00:00
# 4      SYNTHETIC DATASET      BROWN       EARL  1916-01-10 00:00:00
# ...                  ...        ...        ...                  ...
# 41718  SYNTHETIC DATASET    HELLAND      KATHY  1982-05-08 00:00:00
# 41719  SYNTHETIC DATASET    BOSQUET       JOHN  1980-12-25 00:00:00
# 41720  SYNTHETIC DATASET  SHOEMAKER        AMY  1985-04-09 00:00:00
# 41721  SYNTHETIC DATASET     OSBORN       ANDY  1983-09-23 00:00:00
# 41722  SYNTHETIC DATASET      SMITH   JENNIFER  1985-02-05 00:00:00
#
#                 POB          SSN     SEX  STREET NUMBER STREET NAME  \
# 0         ALDERWOOD  970-18-7974    MALE         1355.0      ANGORA
# ...

# %% [markdown]
# ## COUNT DATA

# %%
# how many last name's 
lastname_group = df.groupby(df['LAST NAME'])

lastname_group.count().sort_values(['DOB'], ascending = False).head(20)
# Out:
#            Unnamed: 0  FIRST NAME  DOB  POB  SSN  SEX  STREET NUMBER  \
# LAST NAME
# JOHNSON           337         337  337  337  337  337            336
# SMITH             332         332  332  332  332  332            330
# ANDERSON          280         280  280  280  280  280            278
# JONES             177         177  177  177  177  177            176
# MILLER            177         177  177  177  177  177            176
# BROWN             157         157  157  157  157  157            155
# THOMAS            137         137  137  137  137  137            135
# NELSON            130         130  130  130  130  130            127
# WILLIAMS          130         130  130  130  130  130            127
# LARSON            130         130  130  130  130  130            128
# THOMPSON          128         128  128  128  128  128            126
# ALLEN             124         124  124  124  124  124            123
# ...

# %%
#Date of Birth
dob_group = df.groupby(df['DOB'])

dob_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#                      Unnamed: 0  LAST NAME  FIRST NAME  POB  SSN  SEX  \
# DOB
# 8-Apr-34                     73         73          73   73   73   73
# 1955-06-11 00:00:00           6          6           6    6    6    6
# 1985-01-18 00:00:00           6          6           6    6    6    6
# 1958-03-25 00:00:00           5          5           5    5    5    5
# 1932-05-24 00:00:00           5          5           5    5    5    5
# ...                         ...        ...         ...  ...  ...  ...
# 1921-02-28 00:00:00           1          1           1    1    1    1
# 1921-02-27 00:00:00           1          1           1    1    1    1
# 1980-03-21 00:00:00           1          0           1    1    1    1
# 1928-11-08 00:00:00           1          0           1    1    1    1
# 1976-01-08 00:00:00           1          0           1    1    1    1
#
#                      STREET NUMBER  STREET NAME  VOTER REG DATE  PARTY
# DOB
# ...

# %%
#Place of birth
pob_group = df.groupby(df['POB'])

pob_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#                 Unnamed: 0  LAST NAME  FIRST NAME    DOB    SSN    SEX  \
# POB
# ALDERWOOD            19883      19878       19883  19883  19883  19883
# UTAH                  2782       2782        2782   2782   2782   2782
# ARIZONA               2730       2729        2730   2730   2730   2730
# OREGON                2712       2710        2712   2712   2712   2712
# MONTANA               1894       1893        1894   1894   1894   1894
# MEXICO                1759       1759        1759   1759   1759   1759
# CALIFORNIA            1737       1737        1737   1737   1737   1737
# WASHINGTON            1215       1215        1215   1215   1215   1215
# IDAHO                 1026       1026        1026   1026   1026   1026
# NEW YORK               417        417         417    417    417    417
# WYOMING                327        327         327    327    327    327
# NATURALIZED            286        286         286    286    286    286
# ...

# %% [markdown]
# So interesting that some places in Washington were specificed, example...YAKIMA( a county in Washington state), Mabton (a city in the Yakima county), Spokane(a county in Washington), Alderwood, NATURALIZED (umm?, they had to be born in a country somewhere), Richland(a city in Benton county, Washington State), PASCO (county in florida), Mabton (county in WA), UNK (what is this? Originally thought United Kingdom but that's UK, looked it up and UNK may stand for University of Nebraska??), KENNEWICK(City in Benton county).

# %%
#First name
firstname_group = df.groupby(df['FIRST NAME'])

firstname_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#             Unnamed: 0  LAST NAME  DOB  POB  SSN  SEX  STREET NUMBER  \
# FIRST NAME
# RICHARD            502        502  502  502  502  502            492
# WILLIAM            378        378  378  378  378  378            366
# JOHN               335        335  335  335  335  335            330
# SCOTT              329        328  329  329  329  329            327
# NICOLE             302        302  302  302  302  302            302
# ...                ...        ...  ...  ...  ...  ...            ...
# ELTON                1          1    1    1    1    1              0
# HARRISON             1          1    1    1    1    1              0
# ROBBIE               1          1    1    1    1    1              0
# STERLING             1          1    1    1    1    1              0
# JARROD               1          1    1    1    1    1              0
#
#             STREET NAME  VOTER REG DATE  PARTY
# FIRST NAME
# RICHARD             492             502     502
# ...

# %%
ssn_group = df.groupby(df['SSN'])

ssn_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#              Unnamed: 0  LAST NAME  FIRST NAME  DOB  POB  SEX  STREET NUMBER  \
# SSN
# 001-02-1582           1          1           1    1    1    1              1
# 667-78-6964           1          1           1    1    1    1              1
# 667-39-7619           1          1           1    1    1    1              1
# 667-41-1460           1          1           1    1    1    1              1
# 667-43-4179           1          1           1    1    1    1              1
# ...                 ...        ...         ...  ...  ...  ...            ...
# 337-84-1695           1          1           1    1    1    1              1
# 337-88-4027           1          1           1    1    1    1              1
# 337-88-5513           1          1           1    1    1    1              1
# 337-88-6463           1          1           1    1    1    1              1
# 998-98-8639           1          1           1    1    1    1              1
#
# ...

# %%
#Sex of voter 
sex_group = df.groupby(df['SEX'])

sex_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#         Unnamed: 0  LAST NAME  FIRST NAME    DOB    POB    SSN  STREET NUMBER  \
# SEX
# MALE         21713      21713       21713  21713  21713  21713          20255
# FEMALE       20010      20010       20010  20010  20010  20010          20010
#
#         STREET NAME  VOTER REG DATE  PARTY
# SEX
# MALE          20255           21713   21709
# FEMALE        20010           20010   20010

# %%
street_group = df.groupby(df['STREET NUMBER'])

street_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#                Unnamed: 0  LAST NAME  FIRST NAME  DOB  POB  SSN  SEX  \
# STREET NUMBER
# 35.0                   90         90          90   90   90   90   90
# 175.0                  88         88          88   88   88   88   88
# 245.0                  87         87          87   87   87   87   87
# 105.0                  85         85          85   85   85   85   85
# 140.0                  80         80          80   80   80   80   80
# ...                   ...        ...         ...  ...  ...  ...  ...
# 2391.0                  1          1           1    1    1    1    1
# 2390.0                  1          1           1    1    1    1    1
# 2171.0                  1          1           1    1    1    1    1
# 1920.0                  1          1           1    1    1    1    1
# 23432.0                 1          1           1    1    1    1    1
#
#                STREET NAME  VOTER REG DATE  PARTY
# STREET NUMBER
# 35.0                    90              90      90
# ...

# %%
streetname_group = df.groupby(df['STREET NAME'])

streetname_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#              Unnamed: 0  LAST NAME  FIRST NAME  DOB  POB  SSN  SEX  \
# STREET NAME
# CRANBERRY           502        502         502  502  502  502  502
# TERRIER             287        287         287  287  287  287  287
# TWELVTH             285        285         285  285  285  285  285
# KEESHOND            286        285         286  286  286  286  286
# GINGER              284        284         284  284  284  284  284
# ...                 ...        ...         ...  ...  ...  ...  ...
# BORZOI              223        223         223  223  223  223  223
# MARIGOLD            222        222         222  222  222  222  222
# BALINESE            221        221         221  221  221  221  221
# RAGDOLL             215        215         215  215  215  215  215
# WINDUST               1          1           1    1    1    1    1
#
#              STREET NUMBER  VOTER REG DATE  PARTY
# STREET NAME
# CRANBERRY              502             502     502
# ...

# %%
votreg_group = df.groupby(df['VOTER REG DATE'])

votreg_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#                 Unnamed: 0  LAST NAME  FIRST NAME  DOB  POB  SSN  SEX  \
# VOTER REG DATE
# 1983-11-10             101        101         101  101  101  101  101
# 1983-08-02              62         62          62   62   62   62   62
# 2003-07-20              16         16          16   16   16   16   16
# 2003-01-07              14         14          14   14   14   14   14
# 2003-04-19              14         14          14   14   14   14   14
# ...                    ...        ...         ...  ...  ...  ...  ...
# 1947-05-16               1          1           1    1    1    1    1
# 1947-05-17               1          1           1    1    1    1    1
# 1947-05-18               1          1           1    1    1    1    1
# 1947-05-19               1          1           1    1    1    1    1
# 2004-04-06               1          1           1    1    1    1    1
#
#                 STREET NUMBER  STREET NAME  PARTY
# VOTER REG DATE
# ...

# %%
party_group = df.groupby(df['PARTY '])

party_group.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#              Unnamed: 0  LAST NAME  FIRST NAME    DOB    POB    SSN    SEX  \
# PARTY
# REPUBLICAN        21170      21167       21170  21170  21170  21170  21170
# DEMOCRAT          16374      16368       16374  16374  16374  16374  16374
# INDEPENDENT        2996       2994        2996   2996   2996   2996   2996
# UNDECLARED         1100       1100        1100   1100   1100   1100   1100
# GREEN                40         40          40     40     40     40     40
# LIBERTARIAN          39         39          39     39     39     39     39
#
#              STREET NUMBER  STREET NAME  VOTER REG DATE
# PARTY
# REPUBLICAN           21090        21090           21170
# DEMOCRAT             16215        16215           16374
# INDEPENDENT           2956         2956            2996
# UNDECLARED               0            0            1100
# GREEN                    0            0              40
# LIBERTARIAN              0            0              39

# %% [markdown]
# # Filtering for DOB and POB things to see if there is a pattern

# %%
df_dob_sus = df[df['DOB'] == "8-Apr-34"]

# %%
pob_sus = df_dob_sus.groupby(df['POB'])

pob_sus.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#                 Unnamed: 0  LAST NAME  FIRST NAME  DOB  POB  SSN  SEX  \
# POB
# ALDERWOOD               39         39          39   39   39   39   39
# UTAH                     9          9           9    9    9    9    9
# MEXICO                   4          4           4    4    4    4    4
# OREGON                   3          3           3    3    3    3    3
# WASHINGTON               3          3           3    3    3    3    3
# IDAHO                    2          2           2    2    2    2    2
# GEORGIA                  1          1           1    1    1    1    1
# ILLINOIS                 1          1           1    1    1    1    1
# KANSAS                   1          1           1    1    1    1    1
# KENTUCKY                 1          1           1    1    1    1    1
# MASSACHUSETTS            1          1           1    1    1    1    1
# ARIZONA                  1          1           1    1    1    1    1
# ...

# %%
street_sus = df_dob_sus.groupby(df['STREET NAME'])

street_sus.count().sort_values(['LAST NAME'], ascending = False)
# Out:
#               Unnamed: 0  LAST NAME  FIRST NAME  DOB  POB  SSN  SEX  \
# STREET NAME
# SOMALI                 4          4           4    4    4    4    4
# LILY                   3          3           3    3    3    3    3
# BUFFALOBERRY           3          3           3    3    3    3    3
# CRANBERRY              3          3           3    3    3    3    3
# PRICKLYPEAR            3          3           3    3    3    3    3
# THIRD                  3          3           3    3    3    3    3
# DALMATIAN              2          2           2    2    2    2    2
# HIMALAYA               2          2           2    2    2    2    2
# RAGAMUFFIN             2          2           2    2    2    2    2
# CHOLLA                 2          2           2    2    2    2    2
# DAFFODIL               2          2           2    2    2    2    2
# JAVANESE               2          2           2    2    2    2    2
# SIBERIAN               2          2           2    2    2    2    2
# ...

# %% [markdown]
# ### DOB has to be greater than voter registration by at least 18 years, is this true?

# %% [markdown]
# No this is not true, there are 84 voters whose birth dates did not align with when they were suppose to register to vote.

# %%
#changing date format to match the rest of the dates
df["DOB"].replace({"8-Apr-34": "1934-04-08"},inplace=True)

# %%
#changing the DOB dates to datetime type
df['DOB_2'] =  pd.to_datetime(df['DOB'])
#https://stackoverflow.com/questions/29310116/removing-time-from-datetime-variable-in-pandas

# %%
#converting the registration dates to datetime type
df['VOTER REG DATE'] =  pd.to_datetime(df['VOTER REG DATE'])

# %%
#finding the difference between registration date and dob
df['age_in_days'] = (df['VOTER REG DATE'] - df['DOB_2'])

# %%
#converting the difference from days to years (approximately)
df['age_in_yrs'] = df['age_in_days'] / 365

# %%
voting_age
# Out:
#               Unnamed: 0     LAST NAME FIRST NAME                  DOB  \
# 21     SYNTHETIC DATASET          AMAN     ARLENE  1977-05-01 00:00:00
# 30     SYNTHETIC DATASET         BRAGG       JOSE  1947-03-31 00:00:00
# 50     SYNTHETIC DATASET          BLUE      ISAAC  1961-01-02 00:00:00
# 130    SYNTHETIC DATASET      ZULJEVIC       JOHN  1976-11-30 00:00:00
# 421    SYNTHETIC DATASET         ZHENG       ROSE  1938-08-13 00:00:00
# ...                  ...           ...        ...                  ...
# 32266  SYNTHETIC DATASET        ROMANO       JOHN  1984-05-17 00:00:00
# 32276  SYNTHETIC DATASET           SHI     LAUREN  1984-04-07 00:00:00
# 32280  SYNTHETIC DATASET  SOMASUNDARAM     VICTOR  1984-01-23 00:00:00
# 32282  SYNTHETIC DATASET        SUAREZ      AARON  1983-12-05 00:00:00
# 32288  SYNTHETIC DATASET         WELCH       MIKE  1984-04-29 00:00:00
#
#              POB          SSN     SEX  STREET NUMBER STREET NAME  \
# ...

# %%
# Washington you could register to vote at the age of 16 or 17 and automatically be able to exercise this right as soon as you turn 18 so 16 was the cut off I used. 
voting_age = df[df['age_in_days'] < pd.to_timedelta('5840 days')]

# 0.58% incorrect birth dates 
voting_age
# Out:
#               Unnamed: 0 LAST NAME FIRST NAME                  DOB        POB  \
# 6      SYNTHETIC DATASET    MILLER     GASTON           1934-04-08     OREGON
# 21     SYNTHETIC DATASET      AMAN     ARLENE  1977-05-01 00:00:00    ARIZONA
# 27     SYNTHETIC DATASET  WHITFORD       GERT           1934-04-08  ALDERWOOD
# 30     SYNTHETIC DATASET     BRAGG       JOSE  1947-03-31 00:00:00  ALDERWOOD
# 50     SYNTHETIC DATASET      BLUE      ISAAC  1961-01-02 00:00:00  ALDERWOOD
# ...                  ...       ...        ...                  ...        ...
# 32291  SYNTHETIC DATASET   WINTERS        VAN  1980-05-13 00:00:00  KENNEWICK
# 32292  SYNTHETIC DATASET     WISSE     ARTHUR  1981-03-26 00:00:00  ALDERWOOD
# 32293  SYNTHETIC DATASET     ZHANG       BRET  1982-08-16 00:00:00  ALDERWOOD
# 32294  SYNTHETIC DATASET      ZINN    MICHAEL  1983-09-14 00:00:00  ALDERWOOD
# 32295  SYNTHETIC DATASET       NaN     JOSEPH  1980-03-21 00:00:00   RICHLAND
#
# ...

# %%
#How many of the 242 were not born on the april 8 1934? 169 out of 41723, typos do happen. 0.4% Error rate,by chance? 
voting_age[voting_age['DOB_2'] != '1934-04-08']
# Out:
#               Unnamed: 0 LAST NAME FIRST NAME                  DOB        POB  \
# 21     SYNTHETIC DATASET      AMAN     ARLENE  1977-05-01 00:00:00    ARIZONA
# 30     SYNTHETIC DATASET     BRAGG       JOSE  1947-03-31 00:00:00  ALDERWOOD
# 50     SYNTHETIC DATASET      BLUE      ISAAC  1961-01-02 00:00:00  ALDERWOOD
# 130    SYNTHETIC DATASET  ZULJEVIC       JOHN  1976-11-30 00:00:00  ALDERWOOD
# 371    SYNTHETIC DATASET      AZAD     INGRID  1928-03-17 00:00:00  ALDERWOOD
# ...                  ...       ...        ...                  ...        ...
# 32291  SYNTHETIC DATASET   WINTERS        VAN  1980-05-13 00:00:00  KENNEWICK
# 32292  SYNTHETIC DATASET     WISSE     ARTHUR  1981-03-26 00:00:00  ALDERWOOD
# 32293  SYNTHETIC DATASET     ZHANG       BRET  1982-08-16 00:00:00  ALDERWOOD
# 32294  SYNTHETIC DATASET      ZINN    MICHAEL  1983-09-14 00:00:00  ALDERWOOD
# 32295  SYNTHETIC DATASET       NaN     JOSEPH  1980-03-21 00:00:00   RICHLAND
#
# ...

# %% [markdown]
# # Looking up supsicious names and POB from the articles
# Only one person from switzerland, no one under the name Ellie Omsen.

# %%
#Switzerland is mentioned often in articles, then we had this one person who was born in switzerland vote, is he important in this fishiness? 
df[df['POB'] == 'SWITZERLAND']
# Out:
#               Unnamed: 0 LAST NAME FIRST NAME                  DOB  \
# 26991  SYNTHETIC DATASET      Rinz   Augustus  1957-01-03 00:00:00
#
#                POB          SSN   SEX  STREET NUMBER STREET NAME  \
# 26991  SWITZERLAND  283-23-8943  MALE            2.0    STURGEON
#
#       VOTER REG DATE PARTY       DOB_2       age age_in_days
# 26991     1977-01-07    NaN 1957-01-03 7309 days   7309 days

# %%
# Elli Omsen also seemed to be suspiciousss
#df[df['FIRST NAME'] == 'ELLIE'] NO ONE CAME UP
df[df['LAST NAME'] == 'OMSEN']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, LAST NAME, FIRST NAME, DOB, POB, SSN, SEX, STREET NUMBER, STREET NAME, VOTER REG DATE, PARTY , DOB_2, age_in_days]
# Index: []
